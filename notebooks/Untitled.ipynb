# %%
catalog.load('stocks_table')
# Out:
#                     INFO     Loading data from 'stocks_table' (SQLTableDataSet)...              ]8;id=395648;file://C:\Users\Pedro\Anaconda\envs\kedro-env\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=418017;file://C:\Users\Pedro\Anaconda\envs\kedro-env\Lib\site-packages\kedro\io\data_catalog.py#492\492]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                     date stock_index     open     high      low    close  \
# 0    2022-03-01 09:30:00        AAPL  163.100  163.257  165.071  164.332
# 1    2022-03-01 09:45:00        AAPL  163.942  164.342  165.071  164.282
# 2    2022-03-01 10:00:00        AAPL  163.482  164.303  164.903  163.901
# 3    2022-03-01 10:15:00        AAPL  163.843  163.916  165.161  164.698
# 4    2022-03-01 10:30:00        AAPL  163.526  164.707  164.992  163.589
# ...
